# %%
#%matplotlib inline
#terminal_output = open('/dev/stdout', 'w')
#print('xxx', file=terminal_output)
# %run -i 'backtest.py'
# Out:
# Dropped 2.8% entries from factor data: 2.8% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# Quantiles Statistics
#                     min     max         mean         std   count    count %
# factor_quantile
# 1                   1.0  1011.0   300.240818  187.634400  146513  20.020114
# 2                 352.0  1636.0   850.169443  235.472718  146309  19.992239
# 3                 794.0  2153.0  1408.681749  262.505751  146215  19.979394
# 4                1273.0  2621.0  1971.042766  255.925603  146309  19.992239
# 5                1827.0  3050.0  2511.302281  230.518555  146483  20.016015
# Returns Analysis
#                                                    2D      5D    10D    21D
# Ann. alpha                                      0.045   0.045  0.035  0.009
# beta                                            0.084   0.084  0.098  0.078
# ...
