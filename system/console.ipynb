# %%
import _1_run_backtrader

_1_run_backtrader.main()
# Out:
# ...
# parsing metadata: 100%|██████████| 567/567 [00:01<00:00, 431.97it/s]
# symbol                        SH#688432
# asset_name                          有研硅
# start_date    2022-11-10 00:00:00+00:00
# Name: 0, dtype: object
# SH#688711, 宏微科技 : 100%|██████████| 6/6 [00:00<00:00, 12.18it/s]
# Total data memory cells (6) used: 29820
# <class 'pandas.core.series.Series'>
# Entire data start date: 2020-07-09
# Entire data end date: 2024-02-19
# Backtest months: 41
#                     Backtest
# Annual return          -6.3%
# Cumulative returns    -20.2%
# Annual volatility      22.9%
# Sharpe ratio           -0.17
# Calmar ratio           -0.12
# Stability               0.12
# Max drawdown          -51.7%
# Omega ratio             0.96
# Sortino ratio          -0.24
# Skew                    0.38
# Kurtosis                9.96
# Tail ratio              0.99
# Daily value at risk    -2.9%
# Gross leverage          0.17
# Daily turnover          7.8%
# Alpha                   0.00
# ...
